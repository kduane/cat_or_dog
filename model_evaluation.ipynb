# %%
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.models import load_model

# %%
#load cnn model
cnn = load_model('model')

# %%
sample_path = 'data/cat/Russian Blue/41156128_7499.jpg'
def prep(filepath):
    size = (160, 160)
    img_arr = cv2.imread(sample_path)
    #convert to color array
    img_rgb = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
    #reshape to uniform size 160x160x3
    new_arr = cv2.resize(img_rgb, size)
    #set batch size of 1
    resized = np.expand_dims(new_arr, axis = 0)
    #normalize to match inputs
    normalized = resized / 255
    return normalized

# %%
plt.imshow(cv2.imread(sample_path))

# %%
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)
# Out:
# Device mapping:

# %%
sample = prep(sample_path)
cnn.predict(sample)

# %%
cnn.predict(sample)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b3fd7f4b7f7c> in <module>
# ----> 1 cnn.predict(sample)
#
# NameError: name 'cnn' is not defined
